# %%
# !pip install wandb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import os

from tensorflow.keras.preprocessing import timeseries_dataset_from_array
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import datetime as dt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import Input
from tensorflow.keras.layers import LSTM, GRU, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, TimeDistributed, \
    BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

import wandb
from wandb.keras import WandbCallback

# %%
plt.style.use('fivethirtyeight')
plt.rcParams["figure.figsize"] = (20,12)

# %%
random.seed(hash("random seed") % 2**32 - 1)
np.random.seed(hash("numpy seed") % 2**32 - 1)
tf.random.set_seed(hash("tensorflow seed") % 2**32 - 1)

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
def ts_offset_split(dataframe, steps, lookback, horizon, batch_size, scaler='standard'):
    start = 0
    end = 168
    offset = 24
    training = []
    validation = []

    for i in range(int((365+366)/8)):

        train = dataframe.iloc[start:end]
        val = dataframe.iloc[end:end+offset]
        training.append(train)
        validation.append(val)

        start += 192
        end += 192
    
    # Decide Splits for sets
    train = pd.concat(training)

    val = pd.concat(validation)
    train = train.append(dataframe[(dataframe.index.date > val.index.max()) & (dataframe.index.date < dt.date(2021,1,1))])

    test = dataframe[dataframe.index.date >= dt.date(2021,1,1)]
    
    tmpdf = pd.concat([train,val,test])

    # Scaler
    if scaler == 'standard':
        X_scaler = StandardScaler()
        y_scaler = StandardScaler()
    elif scaler == 'minmax':
        X_scaler = MinMaxScaler()
        y_scaler = MinMaxScaler()
    else:
        print("Please specify one of 'standard' or 'minmax' to scaler parameter.")
    
    # Training
    start = lookback + horizon
    end = start + train.shape[0]

    X_train = train.values
    y_train = tmpdf.iloc[start:end][['Value']]

    X_train = X_scaler.fit_transform(X_train)
    y_train = y_scaler.fit_transform(y_train)

    # Validation
    x_end = len(val) - lookback - horizon
    y_val_start = train.shape[0] + lookback + horizon

    X_val = val.iloc[:x_end]
    y_val = tmpdf.iloc[y_val_start:y_val_start+x_end][['Value']]

    X_val = X_scaler.transform(X_val)
    y_val = y_scaler.transform(y_val)

    # Test
    x_end = len(test) - lookback - horizon
    y_test_start = (train.shape[0] + val.shape[0]) + lookback + horizon

    X_test = test.iloc[:x_end]
    y_test = tmpdf.iloc[y_test_start:y_test_start+x_end][['Value']]

    X_test = X_scaler.transform(X_test)
    y_test = y_scaler.transform(y_test)

    # Batch Sequence Generators
    sequence_length = int(lookback/steps)

    dataset_train = timeseries_dataset_from_array(
        X_train, y_train,
        sequence_length=sequence_length,
        sampling_rate=steps,
        batch_size=batch_size,
        shuffle=True
    )

    dataset_val = timeseries_dataset_from_array(
        X_val, y_val,
        sequence_length=sequence_length,
        sampling_rate=steps,
        batch_size=batch_size,
        shuffle=True
    )    

    dataset_test = timeseries_dataset_from_array(
        X_test, y_test,
        sequence_length=sequence_length,
        sampling_rate=steps,
        batch_size=batch_size,
        shuffle=False
    )    

    return dataset_train, dataset_val, dataset_test

# %%
def load_data(config, splitmethod):
    # Load csv & parse dates to datetime index
    data = pd.read_csv(f'/content/drive/MyDrive/Thesis/{config.dataset}_features.csv', index_col='Datetime', parse_dates=['Datetime'])
    # Select Features
    data = data[['Value', 'sunshine_mins', 'airtemp_c', 'daylength_hrs', 'wkdy_sin', 'wkdy_cos', 'wknd', 'mnth_sin', 'mnth_cos']]
    
    if splitmethod == 'offset':
        train, val, test = ts_offset_split(data, 
                                  steps=steps, lookback=config.lookback, 
                                  horizon=horizon, batch_size=config.batch_size, 
                                  scaler='standard')
    
    elif splitmethod == 'standard':
        train, val, test = create_datasets(data, split=config.splitrate, 
                                  steps=steps, lookback=config.lookback, 
                                  horizon=horizon, batch_size=config.batch_size, 
                                  scaler='standard')
    
    return train, val, test
    
    
def build_model(config):
        
    model = Sequential()

    model.add(Input(shape=(config.lookback, config.num_features)))

    # CNN Block
    model.add(Conv1D(filters=config.cnn_layer_size_1, kernel_size=config.kernelsize, activation=config.activation_cnn))
    model.add(MaxPooling1D(pool_size=2))
    
    # RNN Block  
    model.add(GRU(config.gru_layer_size_1, return_sequences=False, activation=config.activation_gru))
    model.add(Dropout(config.dropout))

    model.add(Dense(1))
    
    opt = config.optimizer
    if opt == 'sgd':
        optimizer = SGD(learning_rate=config.learning_rate, momentum=config.momentum)
        
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
    
    return model

def log_defaults():
    # Default values from the first sweep
    # The following values resulted in the strongest model
    wandb_config = {
        'num_features' : 9,
        'epochs' : 100,
        'batch_size' : 224,
        'optimizer' : 'sgd',
        'dropout' : 0.2,
        'lookback' : 744,
        'activation_cnn' : 'relu',
        'activation_gru' : 'tanh',
        'kernelsize': 3,
        'cnn_layer_size_1' : 56,
        'gru_layer_size_1' : 96,
        'learning_rate' : 0.04,
        'momentum' : 0.9,
        'dataset' : 'strib',
        'splitrate': 0.8,
        'splitmethod': 'offset',
        
    }
    return wandb_config

# %%
# Additional Parameters
steps = 1 # timesteps: 1 hour
horizon = 1 # the target hour in the future we want to predict 1 hour ahead

# %%
stb_data = pd.read_csv(f'/content/drive/MyDrive/Thesis/strib_features.csv', index_col='Datetime', parse_dates=['Datetime'])

start = 0
end = 168
offset = 24
training = []
validation = []

for i in range(int((365+366)/8)):

    stb_train = stb_data.iloc[start:end]
    stb_val = stb_data.iloc[end:end+offset]
    training.append(stb_train)
    validation.append(stb_val)

    start += 192
    end += 192

# Decide Splits for sets
stb_train = pd.concat(training)

stb_val = pd.concat(validation)
stb_train = stb_train.append(stb_data[(stb_data.index.date > stb_val.index.max()) & (stb_data.index.date < dt.date(2021,1,1))])

stb_test = stb_data[stb_data.index.date >= dt.date(2021,1,1)]

train_floats = stb_train[['Value']].to_numpy()
train_mean = train_floats.mean(axis=0)
train_floats -= train_mean
train_std = train_floats.std(axis=0)
train_floats /= train_std

print(f'Standardized Mean: {train_mean},\nStandardized Std: {train_std},\nStandardized Head: {train_floats[:5]}')
# Out:
# Standardized Mean: [52.17963965],
# Standardized Std: [18.33954707],
# Standardized Head: [[ 0.81116291]
#  [ 0.23377678]
#  [ 0.13802742]
#  [-0.16541519]
#  [-0.51755039]]

# %%
wandb.init(config=log_defaults(), group='cnnrnn-final-train-strib', project='thesis')

model = build_model(config=wandb.config)

train, val, test = load_data(config=wandb.config, splitmethod=wandb.config.splitmethod)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=5)

ckpt_path = "/content/drive/MyDrive/Thesis/cnngru_final-strib.h5"
estp = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

ckpt = ModelCheckpoint(
    monitor='val_loss',
    filepath=ckpt_path,
    verbose=1,
    save_weights_only=True,
    save_best_only=True
)

callbacks = [WandbCallback(), reduce_lr, ckpt, estp]

history = model.fit(
    train,
    epochs=wandb.config.epochs,
    validation_data=val,
    callbacks=callbacks
)

eval = model.evaluate(test)
wandb.log({'test_loss': eval[0]})
wandb.log({'test_mae': eval[1]})
print(f'\nTest Loss: {eval[0]} - Test MAE: {eval[1]}')
# Out:
# wandb: Currently logged in as: nbvanting (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">devout-serenity-314</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/nbvanting/thesis" target="_blank">https://wandb.ai/nbvanting/thesis</a><br/>
#                 Run page: <a href="https://wandb.ai/nbvanting/thesis/runs/1iqtye9j" target="_blank">https://wandb.ai/nbvanting/thesis/runs/1iqtye9j</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210515_121155-1iqtye9j</code><br/><br/>
# Epoch 1/100
# 66/66 [==============================] - 38s 77ms/step - loss: 0.6250 - mae: 0.6025 - val_loss: 0.3522 - val_mae: 0.4301
#
# Epoch 00001: val_loss improved from inf to 0.35215, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 2/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.3050 - mae: 0.4106 - val_loss: 0.2851 - val_mae: 0.4038
#
# Epoch 00002: val_loss improved from 0.35215 to 0.28508, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 3/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.2663 - mae: 0.3903 - val_loss: 0.2892 - val_mae: 0.4236
#
# Epoch 00003: val_loss did not improve from 0.28508
# Epoch 4/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.2460 - mae: 0.3761 - val_loss: 0.2477 - val_mae: 0.3904
#
# Epoch 00004: val_loss improved from 0.28508 to 0.24766, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 5/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.2168 - mae: 0.3530 - val_loss: 0.2570 - val_mae: 0.4122
#
# Epoch 00005: val_loss did not improve from 0.24766
# Epoch 6/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.1941 - mae: 0.3371 - val_loss: 0.1964 - val_mae: 0.3461
#
# Epoch 00006: val_loss improved from 0.24766 to 0.19639, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 7/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.1726 - mae: 0.3179 - val_loss: 0.1748 - val_mae: 0.3282
#
# Epoch 00007: val_loss improved from 0.19639 to 0.17475, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 8/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.1503 - mae: 0.3003 - val_loss: 0.1474 - val_mae: 0.2903
#
# Epoch 00008: val_loss improved from 0.17475 to 0.14737, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 9/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.1272 - mae: 0.2730 - val_loss: 0.1497 - val_mae: 0.3017
#
# Epoch 00009: val_loss did not improve from 0.14737
# Epoch 10/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.1187 - mae: 0.2651 - val_loss: 0.1443 - val_mae: 0.2838
#
# Epoch 00010: val_loss improved from 0.14737 to 0.14426, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 11/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.1121 - mae: 0.2575 - val_loss: 0.1229 - val_mae: 0.2661
#
# Epoch 00011: val_loss improved from 0.14426 to 0.12287, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 12/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0992 - mae: 0.2432 - val_loss: 0.1136 - val_mae: 0.2474
#
# Epoch 00012: val_loss improved from 0.12287 to 0.11355, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 13/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0958 - mae: 0.2360 - val_loss: 0.1048 - val_mae: 0.2406
#
# Epoch 00013: val_loss improved from 0.11355 to 0.10479, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 14/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0910 - mae: 0.2309 - val_loss: 0.1045 - val_mae: 0.2434
#
# Epoch 00014: val_loss improved from 0.10479 to 0.10453, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 15/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0875 - mae: 0.2262 - val_loss: 0.1022 - val_mae: 0.2406
#
# Epoch 00015: val_loss improved from 0.10453 to 0.10216, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 16/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0867 - mae: 0.2244 - val_loss: 0.1032 - val_mae: 0.2435
#
# Epoch 00016: val_loss did not improve from 0.10216
# Epoch 17/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0840 - mae: 0.2224 - val_loss: 0.1070 - val_mae: 0.2462
#
# Epoch 00017: val_loss did not improve from 0.10216
# Epoch 18/100
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0819 - mae: 0.2187 - val_loss: 0.0973 - val_mae: 0.2324
#
# Epoch 00018: val_loss improved from 0.10216 to 0.09728, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 19/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0797 - mae: 0.2160 - val_loss: 0.0916 - val_mae: 0.2238
#
# Epoch 00019: val_loss improved from 0.09728 to 0.09158, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 20/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0771 - mae: 0.2128 - val_loss: 0.0958 - val_mae: 0.2286
#
# Epoch 00020: val_loss did not improve from 0.09158
# Epoch 21/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0794 - mae: 0.2160 - val_loss: 0.0930 - val_mae: 0.2270
#
# Epoch 00021: val_loss did not improve from 0.09158
# Epoch 22/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0761 - mae: 0.2122 - val_loss: 0.0934 - val_mae: 0.2250
#
# Epoch 00022: val_loss did not improve from 0.09158
# Epoch 23/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0736 - mae: 0.2075 - val_loss: 0.0920 - val_mae: 0.2264
#
# Epoch 00023: val_loss did not improve from 0.09158
# Epoch 24/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0726 - mae: 0.2073 - val_loss: 0.0911 - val_mae: 0.2211
#
# Epoch 00024: val_loss improved from 0.09158 to 0.09110, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 25/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0715 - mae: 0.2038 - val_loss: 0.0958 - val_mae: 0.2307
#
# Epoch 00025: val_loss did not improve from 0.09110
# Epoch 26/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0721 - mae: 0.2051 - val_loss: 0.0957 - val_mae: 0.2339
#
# Epoch 00026: val_loss did not improve from 0.09110
# Epoch 27/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0739 - mae: 0.2067 - val_loss: 0.0982 - val_mae: 0.2286
#
# Epoch 00027: val_loss did not improve from 0.09110
# Epoch 28/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0744 - mae: 0.2077 - val_loss: 0.0890 - val_mae: 0.2161
#
# Epoch 00028: val_loss improved from 0.09110 to 0.08898, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 29/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0709 - mae: 0.2021 - val_loss: 0.0978 - val_mae: 0.2289
#
# Epoch 00029: val_loss did not improve from 0.08898
# Epoch 30/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0729 - mae: 0.2058 - val_loss: 0.0844 - val_mae: 0.2120
#
# Epoch 00030: val_loss improved from 0.08898 to 0.08438, saving model to /content/drive/MyDrive/Thesis/cnngru_final-strib.h5
# Epoch 31/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0707 - mae: 0.2024 - val_loss: 0.0915 - val_mae: 0.2156
#
# Epoch 00031: val_loss did not improve from 0.08438
# Epoch 32/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0691 - mae: 0.2007 - val_loss: 0.0884 - val_mae: 0.2144
#
# Epoch 00032: val_loss did not improve from 0.08438
# Epoch 33/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0683 - mae: 0.1987 - val_loss: 0.0871 - val_mae: 0.2148
#
# Epoch 00033: val_loss did not improve from 0.08438
# Epoch 34/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0670 - mae: 0.1979 - val_loss: 0.0981 - val_mae: 0.2282
#
# Epoch 00034: val_loss did not improve from 0.08438
# Epoch 35/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0672 - mae: 0.1963 - val_loss: 0.0920 - val_mae: 0.2197
#
# Epoch 00035: val_loss did not improve from 0.08438
# Epoch 36/100
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0660 - mae: 0.1957 - val_loss: 0.0868 - val_mae: 0.2138
#
# Epoch 00036: val_loss did not improve from 0.08438
# Epoch 37/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0646 - mae: 0.1926 - val_loss: 0.0870 - val_mae: 0.2189
#
# Epoch 00037: val_loss did not improve from 0.08438
# Epoch 38/100
# 66/66 [==============================] - 4s 65ms/step - loss: 0.0647 - mae: 0.1930 - val_loss: 0.0846 - val_mae: 0.2122
#
# Epoch 00038: val_loss did not improve from 0.08438
# Epoch 39/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0620 - mae: 0.1883 - val_loss: 0.0857 - val_mae: 0.2146
#
# Epoch 00039: val_loss did not improve from 0.08438
# Epoch 40/100
# 66/66 [==============================] - 4s 64ms/step - loss: 0.0642 - mae: 0.1930 - val_loss: 0.0901 - val_mae: 0.2212
#
# Epoch 00040: val_loss did not improve from 0.08438
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1189 - mae: 0.2544
#
# Test Loss: 0.11888907849788666 - Test MAE: 0.2543529272079468

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 294<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.39MB of 0.39MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210515_121155-1iqtye9j/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210515_121155-1iqtye9j/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>39</td></tr><tr><td>loss</td><td>0.0633</td></tr><tr><td>mae</td><td>0.19204</td></tr><tr><td>val_loss</td><td>0.09013</td></tr><tr><td>val_mae</td><td>0.22121</td></tr><tr><td>_runtime</td><td>221</td></tr><tr><td>_timestamp</td><td>1621080936</td></tr><tr><td>_step</td><td>41</td></tr><tr><td>best_val_loss</td><td>0.08438</td></tr><tr><td>best_epoch</td><td>29</td></tr><tr><td>test_loss</td><td>0.11889</td></tr><tr><td>test_mae</td><td>0.25435</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mae</td><td>█▆▅▅▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▆▅▆▄▃▃▃▃▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_mae</td><td>█▇█▇▇▅▅▄▄▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_mae</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">devout-serenity-314</strong>: <a href="https://wandb.ai/nbvanting/thesis/runs/1iqtye9j" target="_blank">https://wandb.ai/nbvanting/thesis/runs/1iqtye9j</a><br/>

# %%
def plot_training(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    
    epochs = range(len(loss))
    
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "ro-", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
plot_training(history, 'Training History on Strib Dataset')

# %%
pred = model.predict(test)

# %%
inverse_scaled_pred = (pred * train_std) + train_mean
inverse_scaled_pred
# Out:
# array([[51.42935747],
#        [49.26628892],
#        [48.43573851],
#        ...,
#        [55.71039371],
#        [48.35597557],
#        [44.51637213]])

# %%
y_true = stb_test.iloc[744+1:len(stb_test) - 744 + 1][['Value']]

# %%
plt.plot(y_true.iloc[168:2*168].values, label='True')
plt.plot(inverse_scaled_pred[168:2*168], label='Pred')
plt.legend()

# %%
pred_df = y_true.copy()
pred_df.rename(columns={'Value':'True'}, inplace=True)
pred_df['Pred'] = inverse_scaled_pred

# %%
ax = pred_df.plot()
ax.set_title('Predictions vs. True Values for Strib Dataset', fontsize=24)
ax.set_ylabel('kWh')
plt.savefig('/content/drive/MyDrive/Thesis/pred_vs_true_full_strib.png', bbox_inches='tight')
plt.show()

# %%
ax = pred_df.loc[dt.date(2021, )].plot()
ax.set_title('Predictions vs. True Values for Kolding Dataset', fontsize=24)
ax.set_ylabel('kWh')
#plt.savefig('/content/drive/MyDrive/Thesis/pred_vs_true_full_kolding.png', bbox_inches='tight')
plt.show()

# %%
np.mean(np.abs(inverse_scaled_pred - y_true.values))
# Out:
# 4.329919008401973

# %%
np.mean(np.abs((y_true.values - inverse_scaled_pred) / y_true.values)) * 100
# Out:
# 6.0383883534451215

# %%
from tensorflow.keras.losses import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
def metrics(true, pred):
    print(f'MSE: {np.mean(mean_squared_error(true, pred))}')
    print(f'MAE: {np.mean(mean_absolute_error(true, pred))}')
    print(f'MAPE: {np.mean(mean_absolute_percentage_error(true, pred))}')

# %%
metrics(y_true.values, inverse_scaled_pred)
# Out:
# MSE: 35.31615121661694
# MAE: 4.329919008401973
# MAPE: 6.038388353445119
